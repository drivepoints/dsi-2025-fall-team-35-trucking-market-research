# %% [markdown]
# # Predicting NAICS
#
# This notebook uses our small number of companies with NAICS numbers as a training data set to predict the NAICS numbers of other companies.

# %%
import polars as pl
import pandas as pd

# %%
lf = pl.scan_parquet("../data/fully_joined_census_and_data_axle.parquet")
#lf.collect_schema()

# %%
lf = lf.with_columns([
    pl.col("primary_naics_code").cast(str).alias("naics"),
    pl.col("naics8_descriptions").alias("naics_desc")
])

naics = pl.col("naics")

# %%
# Null out NAICS for all unlikely matches.

lf = lf.with_columns(
    pl.when(
        pl.col("best_similarity_name_score") <= 0.8 # Rely on close name matches only.
    ).then(
        pl.lit(None)
    ).otherwise(
        naics
    ).alias("naics")
)

# %%
lf_census = lf.select([pl.col("^[A-Z].*$"), naics])

# %%
df = lf_census.collect()
# Create proxy columns

df = df.with_columns(
    pl.col("PHY_ZIP").str.slice(0,3).alias("ZIP3")
).with_columns(
    pl.col("ZIP3").cast(pl.Categorical)
).with_columns(
    (pl.col("OP_OTHER").is_not_null() & (pl.col("OP_OTHER") != "N"))
    .cast(pl.Int8)  # optional: 0/1
    .alias("has_op_other")
).with_columns([
    # Convert dates
    pl.col("MCS150_DATE").str.strptime(pl.Date, "%d-%b-%y", strict=False).alias("MCS150_DATE_parsed"),
    pl.col("ADD_DATE").str.strptime(pl.Date, "%d-%b-%y", strict=False).alias("ADD_DATE_parsed")
])

# %%
df.select("^.*DATE_parsed$").head()
# Out:
# shape: (5, 2)
# ┌────────────────────┬─────────────────┐
# │ MCS150_DATE_parsed ┆ ADD_DATE_parsed │
# │ ---                ┆ ---             │
# │ date               ┆ date            │
# ╞════════════════════╪═════════════════╡
# │ 2025-01-02         ┆ 2002-01-22      │
# │ 2024-02-09         ┆ 2002-01-22      │
# │ 2023-05-02         ┆ 2002-01-23      │
# │ 2001-08-14         ┆ 2002-01-23      │
# │ 2024-12-06         ┆ 2002-01-23      │
# └────────────────────┴─────────────────┘

# %%
to_drop = [
    "^.*DATE$"
    "^MAILING.*$",
    "^PHY.*$",
    "TELEPHONE",
    "FAX",
    "EMAIL_ADDRESS",
    "OIC_STATE",
    "OP_OTHER"
]   

df = df.drop(to_drop)
df.schema
# Out:
# Schema([('DOT_NUMBER', Int64),
#         ('LEGAL_NAME', String),
#         ('DBA_NAME', String),
#         ('CARRIER_OPERATION', String),
#         ('HM_FLAG', Boolean),
#         ('PC_FLAG', Boolean),
#         ('MCS150_DATE', String),
#         ('MCS150_MILEAGE', Int64),
#         ('MCS150_MILEAGE_YEAR', Int64),
#         ('ADD_DATE', String),
#         ('NBR_POWER_UNIT', Int64),
#         ('DRIVER_TOTAL', Int64),
#         ('RECENT_MILEAGE', Int64),
#         ('RECENT_MILEAGE_YEAR', Int64),
#         ('VMT_SOURCE_ID', Int64),
#         ('PRIVATE_ONLY', Boolean),
#         ('AUTHORIZED_FOR_HIRE', Boolean),
#         ('EXEMPT_FOR_HIRE', Boolean),
#         ('PRIVATE_PROPERTY', Boolean),
#         ('PRIVATE_PASSENGER_BUSINESS', Boolean),
#         ('PRIVATE_PASSENGER_NONBUSINESS', Boolean),
#         ('MIGRANT', Boolean),
#         ('US_MAIL', Boolean),
#         ('FEDERAL_GOVERNMENT', Boolean),
#         ('STATE_GOVERNMENT', Boolean),
#         ('LOCAL_GOVERNMENT', Boolean),
#         ('INDIAN_TRIBE', Boolean),
#         ('naics', String),
#         ('ZIP3', Categorical),
#         ('has_op_other', Int8)])

# %%
df["OP_OTHER"].value_counts(sort=True)
# Out:
# shape: (13_750, 2)
# ┌─────────────────────────────────┬─────────┐
# │ OP_OTHER                        ┆ count   │
# │ ---                             ┆ ---     │
# │ str                             ┆ u32     │
# ╞═════════════════════════════════╪═════════╡
# │ N                               ┆ 2032211 │
# │ APPLYING FOR MC                 ┆ 16650   │
# │ UNKNOWN                         ┆ 3418    │
# │ FARMER                          ┆ 2183    │
# │ FARM                            ┆ 2029    │
# │ …                               ┆ …       │
# │ MECHANIC REPAIR                 ┆ 1       │
# │ PUMP INSTALLER                  ┆ 1       │
# │ SERVICING PRIVATE CUSTOMER IN … ┆ 1       │
# │ RAW FOREST PROD                 ┆ 1       │
# │ MOST OF OUR MILEAGE IS IN PICK… ┆ 1       │
# └─────────────────────────────────┴─────────┘

# %%
df_labeled = df.filter(naics.is_not_null())
df_unlabeled = df.filter(naics.is_null())

# %%
pdf = df_labeled.to_pandas()

# %%
pdf.describe()
# Out:
#          DOT_NUMBER  MCS150_MILEAGE  MCS150_MILEAGE_YEAR  NBR_POWER_UNIT  \
# count  1.833980e+05    1.402250e+05        137112.000000   176598.000000
# mean   2.224060e+06    4.184081e+05          2023.266541       29.785541
# std    1.124792e+06    2.554236e+07           139.664865     1871.005656
# min    4.400000e+01    0.000000e+00             0.000000        0.000000
# 25%    1.320160e+06    7.400000e+03          2021.000000        1.000000
# 50%    2.298272e+06    2.500000e+04          2023.000000        2.000000
# 75%    3.063944e+06    9.503700e+04          2024.000000        4.000000
# max    4.460652e+06    7.500075e+09          9900.000000   499995.000000
#
#         DRIVER_TOTAL  RECENT_MILEAGE  RECENT_MILEAGE_YEAR  VMT_SOURCE_ID
# count  183260.000000    1.833980e+05        183398.000000   94781.000000
# mean        8.367904    2.513576e+05          1046.059123       1.031968
# std       278.011770    1.365814e+07          1013.710152       0.247442
# min         0.000000    0.000000e+00             0.000000       1.000000
# 25%         1.000000    0.000000e+00             0.000000       1.000000
# 50%         2.000000    1.000000e+00          2019.000000       1.000000
# 75%         4.000000    4.000000e+04          2024.000000       1.000000
# max     99995.000000    4.000030e+09          9800.000000       3.000000

# %%
df_labeled.schema
# Out:
# Schema([('DOT_NUMBER', Int64),
#         ('LEGAL_NAME', String),
#         ('DBA_NAME', String),
#         ('CARRIER_OPERATION', String),
#         ('HM_FLAG', Boolean),
#         ('PC_FLAG', Boolean),
#         ('PHY_STREET', String),
#         ('PHY_CITY', String),
#         ('PHY_STATE', String),
#         ('PHY_ZIP', String),
#         ('PHY_COUNTRY', String),
#         ('MAILING_STREET', String),
#         ('MAILING_CITY', String),
#         ('MAILING_STATE', String),
#         ('MAILING_ZIP', String),
#         ('MAILING_COUNTRY', String),
#         ('TELEPHONE', String),
#         ('FAX', String),
#         ('EMAIL_ADDRESS', String),
#         ('MCS150_DATE', String),
#         ('MCS150_MILEAGE', Int64),
#         ('MCS150_MILEAGE_YEAR', Int64),
#         ('ADD_DATE', String),
#         ('OIC_STATE', String),
#         ('NBR_POWER_UNIT', Int64),
#         ('DRIVER_TOTAL', Int64),
#         ('RECENT_MILEAGE', Int64),
#         ('RECENT_MILEAGE_YEAR', Int64),
#         ('VMT_SOURCE_ID', Int64),
#         ('PRIVATE_ONLY', Boolean),
#         ('AUTHORIZED_FOR_HIRE', Boolean),
#         ('EXEMPT_FOR_HIRE', Boolean),
#         ('PRIVATE_PROPERTY', Boolean),
#         ('PRIVATE_PASSENGER_BUSINESS', Boolean),
#         ('PRIVATE_PASSENGER_NONBUSINESS', Boolean),
#         ('MIGRANT', Boolean),
#         ('US_MAIL', Boolean),
#         ('FEDERAL_GOVERNMENT', Boolean),
#         ('STATE_GOVERNMENT', Boolean),
#         ('LOCAL_GOVERNMENT', Boolean),
#         ('INDIAN_TRIBE', Boolean),
#         ('OP_OTHER', String),
#         ('naics', String)])

# %%
pdf.head()
# Out:
#    DOT_NUMBER                    LEGAL_NAME DBA_NAME CARRIER_OPERATION  \
# 0     1000021             LEITZA EXCAVATING     None                 C
# 1     1000022  MACHINE TOOL & EQUIPMENT INC     None                 C
# 2     1000096             TULL BROTHERS INC     None                 C
# 3     1000123       JENSEN POURED WALLS INC     None                 C
# 4     1000209           PARMAR CARRIERS INC     None                 A
#
#    HM_FLAG  PC_FLAG             PHY_STREET     PHY_CITY PHY_STATE PHY_ZIP  \
# 0    False    False   230236 COLONIAL ROAD       WAUSAU        WI   54403
# 1    False    False   145536 COUNTY ROAD U       WAUSAU        WI   54401
# 2    False    False     66 NEW BRITAIN AVE   ROCKY HILL        CT   06067
# 3    False    False    204 WATERLOO STREET     COLUMBUS        WI   53925
# 4    False    False  4929 SAN PABLO DAM RD  EL SOBRANTE        CA   94803
#
#    ... PRIVATE_PASSENGER_BUSINESS PRIVATE_PASSENGER_NONBUSINESS MIGRANT  \
# 0  ...                      False                         False   False
# 1  ...                      False                         False   False
# 2  ...                      False                         False   False
# 3  ...                      False                         False   False
# 4  ...                      False                         False   False
#
#   US_MAIL FEDERAL_GOVERNMENT STATE_GOVERNMENT LOCAL_GOVERNMENT INDIAN_TRIBE  \
# 0   False              False            False            False        False
# 1   False              False            False            False        False
# 2   False              False            False            False        False
# 3   False              False            False            False        False
# 4   False              False            False            False        False
#
#   OP_OTHER     naics
# 0        N  23891006
# 1        N  42383045
# 2        N  42371011
# 3        N  23811001
# 4        N  99999004
#
# [5 rows x 43 columns]
